# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Import et premier aperçu

# %%
#read the data
sd_train=pd.read_csv("counterfeit_train.csv")
sd_test=pd.read_csv("counterfeit_test.csv")

# %%
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_columns', 50)

# %%
#premier contact avec le dataset

sd_train.describe()
# Out:
#        Counterfeit_Weight  Active_Since  Medicine_MRP  Availability_rating  \
# count         5652.000000   6818.000000   6818.000000          6818.000000
# mean            14.115057   1995.836316    151.401518             0.079174
# std              4.649668      8.368979     62.203961             0.051481
# min              5.855000   1983.000000     41.790000             0.013000
# 25%              9.995000   1985.000000    104.509400             0.040058
# 50%             13.800000   1997.000000    153.195700             0.066955
# 75%             18.050000   2002.000000    196.148350             0.107697
# max             22.650000   2007.000000    277.188400             0.341391
#
#        Counterfeit_Sales
# count        6818.000000
# mean         2280.583480
# std          1693.354404
# min           146.290000
# 25%           933.265600
# 50%          1902.670400
# 75%          3207.638400
# max         13199.964800

# %%
sd_train.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       RRA15              13.100     Area046          1995      160.2366
# 1       YVV26                 NaN     Area027          1983      110.4384
# 2       LJC15               9.025     Area046          1995      259.4092
# 3       GWC40              11.800     Area046          1995       99.9830
# 4       QMN13                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales
# 0            DownTown         Tier 1           Small          1775.5026
# ...

# %%
sd_train.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       RRA15              13.100     Area046          1995      160.2366
# 1       YVV26                 NaN     Area027          1983      110.4384
# 2       LJC15               9.025     Area046          1995      259.4092
# 3       GWC40              11.800     Area046          1995       99.9830
# 4       QMN13                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales
# 0            DownTown         Tier 1           Small          1775.5026
# ...

# %%
sd_test.head()
# Out:
#   Medicine_ID  Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0       HLZ81                 NaN     Area027          1983       85.5328
# 1       ECE94               13.45     Area045          2000      257.1460
# 2       SAD14                7.10     Area045          2000       98.1172
# 3       EQV63               18.30     Area010          1996      135.3730
# 4       AIR10                 NaN     Area019          1983      112.8016
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0         Antibiotics            mild             0.112747
# 1  OralContraceptives            mild             0.144446
# 2        Antipyretics            mild             0.144221
# 3       Tranquilizers            mild             0.100388
# 4  OralContraceptives            mild             0.022585
#
#             Area_Type Area_City_Type Area_dist_level
# 0          CityLimits         Tier 3          Medium
# 1            DownTown         Tier 2         Unknown
# ...

# %%
sd_train.shape
# Out:
# (6818, 12)

# %%
sd_test.shape
# Out:
# (1705, 11)

# %%
sd_train.columns
# Out:
# Index(['Medicine_ID', 'Counterfeit_Weight', 'DistArea_ID', 'Active_Since',
#        'Medicine_MRP', 'Medicine_Type', 'SidEffect_Level',
#        'Availability_rating', 'Area_Type', 'Area_City_Type', 'Area_dist_level',
#        'Counterfeit_Sales'],
#       dtype='object')

# %%
sd_test.columns
# Out:
# Index(['Medicine_ID', 'Counterfeit_Weight', 'DistArea_ID', 'Active_Since',
#        'Medicine_MRP', 'Medicine_Type', 'SidEffect_Level',
#        'Availability_rating', 'Area_Type', 'Area_City_Type',
#        'Area_dist_level'],
#       dtype='object')

# %%
for i in sd_train.columns :
    print(i + ' : ' ,sd_train[i].isna().sum()) #on releve les NaN
# Out:
# Medicine_ID :  0
# Counterfeit_Weight :  1166
# DistArea_ID :  0
# Active_Since :  0
# Medicine_MRP :  0
# Medicine_Type :  0
# SidEffect_Level :  0
# Availability_rating :  0
# Area_Type :  0
# Area_City_Type :  0
# Area_dist_level :  0
# Counterfeit_Sales :  0

# %%
for i in sd_train.columns :
    print(i + ' : ',sd_train[i].dtype) #on identifie les features quantitatives et qualitatives
# Out:
# Medicine_ID :  object
# Counterfeit_Weight :  float64
# DistArea_ID :  object
# Active_Since :  int64
# Medicine_MRP :  float64
# Medicine_Type :  object
# SidEffect_Level :  object
# Availability_rating :  float64
# Area_Type :  object
# Area_City_Type :  object
# Area_dist_level :  object
# Counterfeit_Sales :  float64

# %%
for i in sd_train.columns :
    print(i + ' : ',sd_train[i].value_counts(dropna = False))
# Out:
# Medicine_ID :  SCK30    9
# OQH15    9
# KIS14    9
# QLK14    9
# RQS74    9
#         ..
# KGC13    1
# UTM98    1
# YYX14    1
# QEG60    1
# PIG89    1
# Name: Medicine_ID, Length: 1557, dtype: int64
# Counterfeit_Weight :  NaN       1166
# 13.450      72
# 18.900      67
# 13.100      65
# 18.000      55
#           ...
# 10.220       1
# 8.985        1
# 8.075        1
# 8.195        1
# 7.035        1
# Name: Counterfeit_Weight, Length: 415, dtype: int64
# DistArea_ID :  Area017    760
# Area013    749
# Area046    749
# Area035    748
# Area049    739
# Area045    736
# Area027    735
# Area018    729
# Area010    442
# Area019    431
# Name: DistArea_ID, dtype: int64
# Active_Since :  1983    1166
# 2005     760
# 1995     749
# 1985     749
# 2002     748
# 1997     739
# 2000     736
# 2007     729
# 1996     442
# Name: Active_Since, dtype: int64
# Medicine_MRP :  152.3154    6
# 182.3422    5
# 137.4020    5
# 131.1756    5
# 119.8228    5
#            ..
# ...

# %% [markdown]
# # Visualisation et exploration

# %% [markdown]
# # 1) cat variables

# %%
from matplotlib import pyplot

fig, ax = pyplot.subplots(figsize=(30,15))


sns.violinplot(x ="Medicine_Type", y ="Counterfeit_Sales", hue ="SidEffect_Level",
data = sd_train, split = True,)

#pas d'effet notable de la sévérité des effets secondaires sur les ventes de médicaments contrefaits sauf pour les antiviraux
# Out:
# <AxesSubplot:xlabel='Medicine_Type', ylabel='Counterfeit_Sales'>

# %%
fig, ax = pyplot.subplots(figsize=(25,15))


sns.violinplot(x ="DistArea_ID", y ="Counterfeit_Sales", hue ="SidEffect_Level",
data = sd_train, split = True,)

# les zones 19 et 10 connaissent relativement peu de ventes de contrefaçons
# Out:
# <AxesSubplot:xlabel='DistArea_ID', ylabel='Counterfeit_Sales'>

# %%
fig, ax = pyplot.subplots(figsize=(25,15))


sns.violinplot(x ="Area_Type", y ="Counterfeit_Sales", hue ="SidEffect_Level",
data = sd_train, split = True,)

# les zones périurbaines présentent beaucoup moins de ventes illégales
# Out:
# <AxesSubplot:xlabel='Area_Type', ylabel='Counterfeit_Sales'>

# %%
fig, ax = pyplot.subplots(figsize=(25,15))


sns.violinplot(x ="Area_City_Type", y ="Counterfeit_Sales", hue ="SidEffect_Level",
data = sd_train, split = True,)
# Out:
# <AxesSubplot:xlabel='Area_City_Type', ylabel='Counterfeit_Sales'>

# %%
sd_train.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'Counterfeit_Weight'}>,
#         <AxesSubplot:title={'center':'Active_Since'}>],
#        [<AxesSubplot:title={'center':'Medicine_MRP'}>,
#         <AxesSubplot:title={'center':'Availability_rating'}>],
#        [<AxesSubplot:title={'center':'Counterfeit_Sales'}>,
#         <AxesSubplot:>]], dtype=object)

# %% [markdown]
# # 2) numeric variables

# %%
fig, ax = pyplot.subplots(figsize=(20,10))

sns.regplot(x="Medicine_MRP", y="Counterfeit_Sales", color= 'green',data=sd_train)

#influence notable du Medecine MRP sur la target
# Out:
# <AxesSubplot:xlabel='Medicine_MRP', ylabel='Counterfeit_Sales'>

# %%
fig, ax = pyplot.subplots(figsize=(20,10))

sns.scatterplot(x="Availability_rating", y="Counterfeit_Sales", color= 'blue',data=sd_train)
# Out:
# <AxesSubplot:xlabel='Availability_rating', ylabel='Counterfeit_Sales'>

# %%
fig, ax = pyplot.subplots(figsize=(20,10))

sns.scatterplot(x="Counterfeit_Weight", y="Counterfeit_Sales", color= 'red',data=sd_train)
# Out:
# <AxesSubplot:xlabel='Counterfeit_Weight', ylabel='Counterfeit_Sales'>

# %%
sns.heatmap(sd_train.corr(), annot=True,)   #correlations entre les features num
# Out:
# <AxesSubplot:>

# %%
fig, ax = pyplot.subplots(figsize=(20,10))

sns.kdeplot(x="Counterfeit_Sales", data=sd_train)   # distribution de la target

# asymétrique vers la gauche ( ~gaussienne décalée)
# Out:
# <AxesSubplot:xlabel='Counterfeit_Sales', ylabel='Density'>

# %% [markdown]
# # Pre processing

# %%
sd_train.drop(['Medicine_ID'], axis = 1, inplace = True) #on supprime la colonne d'identifiants ( 1557 valeurs uniques donc risque d'overfitting dans l'apprentissage)

# %%
sd_test.drop(['Medicine_ID'], axis = 1, inplace = True)

# %%
sd_train.head()
# Out:
#    Counterfeit_Weight DistArea_ID  Active_Since  Medicine_MRP  \
# 0              13.100     Area046          1995      160.2366
# 1                 NaN     Area027          1983      110.4384
# 2               9.025     Area046          1995      259.4092
# 3              11.800     Area046          1995       99.9830
# 4                 NaN     Area019          1983       56.4402
#
#         Medicine_Type SidEffect_Level  Availability_rating  \
# 0        Antimalarial        critical             0.070422
# 1         Mstablizers            mild             0.013000
# 2             Cardiac            mild             0.060783
# 3  OralContraceptives            mild             0.065555
# 4       Hreplacements        critical             0.248859
#
#             Area_Type Area_City_Type Area_dist_level  Counterfeit_Sales
# 0            DownTown         Tier 1           Small          1775.5026
# 1          CityLimits         Tier 3          Medium          3069.1520
# ...

# %%
sd_train_encoded = pd.get_dummies(sd_train,
columns=['DistArea_ID','Medicine_Type','SidEffect_Level','Area_Type','Area_City_Type','Area_dist_level']) #encodage one hot pour les variables catégorielles

# %%
sd_test_encoded = pd.get_dummies(sd_test,
columns=['DistArea_ID','Medicine_Type','SidEffect_Level','Area_Type','Area_City_Type','Area_dist_level'])

# %%
sd_train_encoded.shape
# Out:
# (6818, 44)

# %%
sd_test_encoded.shape
# Out:
# (1705, 43)

# %%
# On essaie différentes strategy d'imputing ( pas de différence notable finalement même si le KNN est donne un meilleur mae par la suite)
from sklearn.impute import SimpleImputer
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.impute import KNNImputer

imp0 = SimpleImputer(strategy='median')
imp1 = IterativeImputer(max_iter=30, random_state=0)
imp2 = KNNImputer(n_neighbors=10, weights="uniform",)

# %%
sd_train_impute0 = pd.DataFrame(imp0.fit_transform(sd_train_encoded), columns = sd_train_encoded.columns) #on impute
sd_train_impute1 = pd.DataFrame(imp1.fit_transform(sd_train_encoded), columns = sd_train_encoded.columns)
sd_train_impute2 = pd.DataFrame(imp2.fit_transform(sd_train_encoded), columns = sd_train_encoded.columns)

# %%
sd_test_impute2 = pd.DataFrame(imp2.fit_transform(sd_test_encoded), columns = sd_test_encoded.columns)

# %%
sd_train_impute0.Counterfeit_Weight
# Out:
# 0       13.100
# 1       13.800
# 2        9.025
# 3       11.800
# 4       13.800
#          ...
# 6813     8.535
# 6814    20.650
# 6815    20.000
# 6816    10.180
# 6817     7.930
# Name: Counterfeit_Weight, Length: 6818, dtype: float64

# %%
sd_train_impute1.Counterfeit_Weight
# Out:
# 0       13.100000
# 1       13.843799
# 2        9.025000
# 3       11.800000
# 4       14.087482
#           ...
# 6813     8.535000
# 6814    20.650000
# 6815    20.000000
# 6816    10.180000
# 6817     7.930000
# Name: Counterfeit_Weight, Length: 6818, dtype: float64

# %%
sd_train_impute2.Counterfeit_Weight
# Out:
# 0       13.100
# 1       12.488
# 2        9.025
# 3       11.800
# 4       14.833
#          ...
# 6813     8.535
# 6814    20.650
# 6815    20.000
# 6816    10.180
# 6817     7.930
# Name: Counterfeit_Weight, Length: 6818, dtype: float64

# %% [markdown]
# # test & train set

# %%
from sklearn.model_selection import train_test_split

# %%
sd_train1,sd_train2=train_test_split(sd_train_impute2,test_size=0.2,random_state=2)

# %%
x_train1=sd_train1.drop('Counterfeit_Sales',axis=1)

y_train1=sd_train1['Counterfeit_Sales']

# %%
x_train1.shape
# Out:
# (5454, 43)

# %%
y_train1.shape
# Out:
# (5454,)

# %% [markdown]
# # linear regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lm=LinearRegression()

# %%
lm.fit(x_train1,y_train1)  #entrainement sur un modèle simple
# Out:
# LinearRegression()

# %%
lm.intercept_
# Out:
# 27763.76313431512

# %%
list(zip(x_train1.columns,lm.coef_))  #on fait apparaître le coeff ( le poids) de chaque feature dans 
                                        #le modèle de regression
# Out:
# [('Counterfeit_Weight', -4.1698600828849495),
#  ('Active_Since', -13.639690354534045),
#  ('Medicine_MRP', 15.56860494350681),
#  ('Availability_rating', -261.0377420163911),
#  ('DistArea_ID_Area010', -417.3785411591154),
#  ('DistArea_ID_Area013', -80.79388716921777),
#  ('DistArea_ID_Area017', 216.28127387669102),
#  ('DistArea_ID_Area018', -91.73706407955702),
#  ('DistArea_ID_Area019', -462.9079485272724),
#  ('DistArea_ID_Area027', 593.1636275875675),
#  ('DistArea_ID_Area035', 62.6676492122455),
#  ('DistArea_ID_Area045', -33.75889656171394),
#  ('DistArea_ID_Area046', 300.95323864705284),
#  ('DistArea_ID_Area049', -86.48945182668037),
#  ('Medicine_Type_Analgesics', -20.12591473913474),
#  ('Medicine_Type_Antacids', -2.3918229735158927),
#  ('Medicine_Type_Antibiotics', 35.04834368396777),
#  ('Medicine_Type_Antifungal', -35.056831554532685),
#  ('Medicine_Type_Antimalarial', -53.717048815927335),
#  ('Medicine_Type_Antipyretics', -71.58971671016549),
# ...

# %%
x_train2=sd_train2.drop('Counterfeit_Sales',axis=1)

# %%
predicted_ir=lm.predict(x_train2)

# %%
print(predicted_ir)
# Out:
# [1034.5145691   857.59510853 3881.62487597 ... 1646.31562868 3911.60577527
#  1709.45531539]

# %%
#on vérifie la performance sur le set de validation en choisissant la métrique mae

from sklearn.metrics import mean_absolute_error

ytest=sd_train2['Counterfeit_Sales']
mae=mean_absolute_error(ytest,predicted_ir)
print(mae)
# Out:
# 830.1755504136635

# %%
from sklearn.metrics import median_absolute_error
ytest=sd_train2['Counterfeit_Sales'] #on vérifie la performance sur le set de validation avec la métrique median absolute error
                                    #la medae est moins "punitive" pour les valeurs extrêmes ( qui s'éloignent de la moyenne)
medae=median_absolute_error(ytest,predicted_ir)
print(medae)
# Out:
# 615.516111422948

# %%
x_train=sd_train_impute2.drop('Counterfeit_Sales',axis=1)
y_train=sd_train_impute2['Counterfeit_Sales']

# %%
lm.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
test_pred=lm.predict(sd_test_impute2) #on réalise la prédiction sur le set de test
test_pred
# Out:
# array([2795.44861695, 3916.20608884, 1429.55683993, ..., 2893.02676586,
#        3870.95707418, 3750.96755078])

# %% [markdown]
# # Ridge  Regression

# %%
from sklearn.linear_model import Ridge
from sklearn.model_selection import GridSearchCV

# %%
lambdas=np.linspace(1,100,1000)

# %%
params={'alpha':lambdas}

# %%
model=Ridge(fit_intercept=True)

# %%
grid_search=GridSearchCV(model,param_grid=params,cv=50,scoring='neg_mean_absolute_error') 

#On recherche les meilleurs hyperparamètres sur le critère de la mae

# %%
grid_search.fit(x_train1,y_train1)
# Out:
# GridSearchCV(cv=50, estimator=Ridge(),
#              param_grid={'alpha': array([  1.        ,   1.0990991 ,   1.1981982 ,   1.2972973 ,
#          1.3963964 ,   1.4954955 ,   1.59459459,   1.69369369,
#          1.79279279,   1.89189189,   1.99099099,   2.09009009,
#          2.18918919,   2.28828829,   2.38738739,   2.48648649,
#          2.58558559,   2.68468468,   2.78378378,   2.88288288,
#          2.98198198,   3.08108108,   3.18018018,   3.27927928,
#          3.37837838,   3.47747748,   3.57657658,   3....
#         97.32432432,  97.42342342,  97.52252252,  97.62162162,
#         97.72072072,  97.81981982,  97.91891892,  98.01801802,
#         98.11711712,  98.21621622,  98.31531532,  98.41441441,
#         98.51351351,  98.61261261,  98.71171171,  98.81081081,
#         98.90990991,  99.00900901,  99.10810811,  99.20720721,
#         99.30630631,  99.40540541,  99.5045045 ,  99.6036036 ,
#         99.7027027 ,  99.8018018 ,  99.9009009 , 100.        ])},
# ...

# %%
grid_search.best_estimator_

# %%
grid_search.best_score_

# %%
test_pred1 = grid_search.predict(sd_test_impute2)  # prédiction sur le test set
test_pred1
# Out:
# array([2721.5497263 , 3937.71333539, 1454.25792754, ..., 2893.37329608,
#        3871.2741315 , 3756.15554471])

# %% [markdown]
# # XGB regressor

# %%
pip install xgboost
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import xgboost as xgb
from xgboost.sklearn import XGBRegressor

# %%
xgb1 = XGBRegressor()
parameters = { 
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07],
              'max_depth': [4, 5, 6, 7,8],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.5, 0.7, 0.9],
              'colsample_bytree': [0.7],
              'n_estimators': [500,800,1200]}

xgb_grid = GridSearchCV(xgb1,                                     #On recherche les meilleurs hyperparamètres sur le critère de la mae
                        parameters,
                        cv = 10,
                        n_jobs = -1,
                        verbose=True, scoring = 'neg_mean_absolute_error')

xgb_grid.fit(x_train1,y_train1)

print(xgb_grid.best_score_) 
print(xgb_grid.best_params_)
# Out:
# Fitting 10 folds for each of 135 candidates, totalling 1350 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:  3.3min
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-237-09d90ae4fd15> in <module>
#      16                         verbose=True, scoring = 'neg_mean_absolute_error')
#      17
# ---> 18 xgb_grid.fit(x_train1,y_train1)
#      19
#      20 print(xgb_grid.best_score_)
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ...

# %%
xgb2 = XGBRegressor(colsample_bytree = 0.7, learning_rate = 0.03, max_depth = 4, min_child_weight =  4, n_estimators = 500, objective = 'reg:linear', subsample = 0.9)

# %%
xgb2.fit(x_train1,y_train1)
# Out:
# [16:52:06] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/objective/regression_obj.cu:188: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.7, enable_categorical=False,
#              gamma=0, gpu_id=-1, importance_type=None,
#              interaction_constraints='', learning_rate=0.03, max_delta_step=0,
#              max_depth=4, min_child_weight=4, missing=nan,
#              monotone_constraints='()', n_estimators=500, n_jobs=8,
#              num_parallel_tree=1, objective='reg:linear', predictor='auto',
#              random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#              subsample=0.9, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
pred = xgb2.predict(x_train2)

# %%
ytest=sd_train2['Counterfeit_Sales']

mae=mean_absolute_error(ytest,pred)

print(mae)
# Out:
# 766.8255244980172

# %%
test_pred2 = xgb_grid.predict(sd_test_impute2)   # prédiction pour le test set
test_pred2
# Out:
# array([2291.424 , 3763.1013, 1380.6458, ..., 3002.9932, 2782.1687,
#        3891.349 ], dtype=float32)
